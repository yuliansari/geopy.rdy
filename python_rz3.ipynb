# %%
pip install geopandas

# %%
import geopandas

# %%
import geopandas as gpd

# %%
in_geojson = r'/content/data3/ADMINISTRASIKECAMATAN_AR_50K.geojson'
in_shp = r'/content/data3/ADMINISTRASIKECAMATAN_AR_50K.shp'

# %%
gdf = gpd.read_file(in_geojson)

# %%
gdf.head()
# Out:
#   KDPPUM            NAMOBJ                          REMARK KDPBPS FCODE  \
# 0   None          ULU OGAN  Wilayah Administrasi Kecamatan   None  None
# 1   None         MUARAJAYA  Wilayah Administrasi Kecamatan   None  None
# 2   None        PENGADONAN  Wilayah Administrasi Kecamatan   None  None
# 3   None  SEMENDEDARATLAUT  Wilayah Administrasi Kecamatan   None  None
# 4   None       SEMIDANGAJI  Wilayah Administrasi Kecamatan   None  None
#
#    LUASWH  UUPP SRS_ID   LCODE METADATA  ... WADMKC WIADKC            WADMKK  \
# 0     0.0  None   None  BA0080     None  ...   None   None  OGANKOMERING ULU
# 1     0.0  None   None  BA0080     None  ...   None   None  OGANKOMERING ULU
# 2     0.0  None   None  BA0080     None  ...   None   None  OGANKOMERING ULU
# 3     0.0  None   None  BA0080     None  ...   None   None         MUARAENIM
# 4     0.0  None   None  BA0080     None  ...   None   None  OGANKOMERING ULU
#
#   WIADKK            WADMPR WIADPR TIPADM Shape_Leng Shape_Area  \
# ...

# %%
gdf.head(43)
# Out:
#    KDPPUM               NAMOBJ                          REMARK KDPBPS FCODE  \
# 0    None             ULU OGAN  Wilayah Administrasi Kecamatan   None  None
# 1    None            MUARAJAYA  Wilayah Administrasi Kecamatan   None  None
# 2    None           PENGADONAN  Wilayah Administrasi Kecamatan   None  None
# 3    None     SEMENDEDARATLAUT  Wilayah Administrasi Kecamatan   None  None
# 4    None          SEMIDANGAJI  Wilayah Administrasi Kecamatan   None  None
# 5    None          PAGARGUNUNG  Wilayah Administrasi Kecamatan   None  None
# 6    None          LUBUKBATANG  Wilayah Administrasi Kecamatan   None  None
# 7    None         TANJUNGAGUNG  Wilayah Administrasi Kecamatan   None  None
# 8    None       MERAPI SELATAN  Wilayah Administrasi Kecamatan   None  None
# 9    None           PENINJAUAN  Wilayah Administrasi Kecamatan   None  None
# 10   None            LUBAI ULU  Wilayah Administrasi Kecamatan   None  None
# ...

# %%
in_shp = r'/content/data3/ADMINISTRASIKECAMATAN_AR_50K.shp'

# %%
gdf = gpd.read_file(in_shp)

# %%
from sqlalchemy import create_engine
db_connection_url = "postgres://myusername:mypassword@myhost:5432/mydb"
con = create_engine(db_connection_url)
sql = "SELECT geom, highway FROM roads"
df = geopandas.GeoDataFrame.from_postgis(sql, con)
# Out:
# ---------------------------------------------------------------------------
# NoSuchModuleError                         Traceback (most recent call last)
# <ipython-input-11-52a28bdbb359> in <cell line: 3>()
#       1 from sqlalchemy import create_engine
#       2 db_connection_url = "postgres://myusername:mypassword@myhost:5432/mydb"
# ----> 3 con = create_engine(db_connection_url)
#       4 sql = "SELECT geom, highway FROM roads"
#       5 df = geopandas.GeoDataFrame.from_postgis(sql, con)
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/create.py in create_engine(url, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     279                         stacklevel=3,
#     280                     )
# --> 281             return fn(*args, **kwargs)  # type: ignore[no-any-return]
#     282
#     283         doc = fn.__doc__ is not None and fn.__doc__ or ""
#
# ...

# %%
from sqlalchemy import create_engine
db_connection_url = "postgres://myusername:mypassword@myhost:5432/mydb"
con = create_engine(db_connection_url)
sql = "SELECT geom, highway FROM roads"
df = geopandas.GeoDataFrame.from_postgis(sql, con)
# Out:
# ---------------------------------------------------------------------------
# NoSuchModuleError                         Traceback (most recent call last)
# <ipython-input-34-52a28bdbb359> in <cell line: 3>()
#       1 from sqlalchemy import create_engine
#       2 db_connection_url = "postgres://myusername:mypassword@myhost:5432/mydb"
# ----> 3 con = create_engine(db_connection_url)
#       4 sql = "SELECT geom, highway FROM roads"
#       5 df = geopandas.GeoDataFrame.from_postgis(sql, con)
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/create.py in create_engine(url, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     279                         stacklevel=3,
#     280                     )
# --> 281             return fn(*args, **kwargs)  # type: ignore[no-any-return]
#     282
#     283         doc = fn.__doc__ is not None and fn.__doc__ or ""
#
# ...

# %%
len(gdf)
# Out:
# 43

# %%
gdf.crs
# Out:
# <Compound CRS: EPSG:9518>
# Name: WGS 84 + EGM2008 height
# Axis Info [ellipsoidal|vertical]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# - H[up]: Gravity-related height (metre)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich
# Sub CRS:
# - WGS 84
# - EGM2008 height

# %%
gdf.geom_type
# Out:
# 0          Polygon
# 1     MultiPolygon
# 2     MultiPolygon
# 3     MultiPolygon
# 4     MultiPolygon
# 5     MultiPolygon
# 6          Polygon
# 7          Polygon
# 8     MultiPolygon
# 9     MultiPolygon
# 10         Polygon
# 11         Polygon
# 12    MultiPolygon
# 13         Polygon
# 14         Polygon
# 15         Polygon
# 16    MultiPolygon
# 17    MultiPolygon
# 18    MultiPolygon
# 19         Polygon
# 20         Polygon
# 21         Polygon
# 22         Polygon
# 23    MultiPolygon
# 24         Polygon
# 25    MultiPolygon
# 26         Polygon
# 27    MultiPolygon
# 28         Polygon
# 29         Polygon
# 30    MultiPolygon
# 31    MultiPolygon
# 32    MultiPolygon
# 33    MultiPolygon
# 34    MultiPolygon
# 35         Polygon
# 36    MultiPolygon
# 37         Polygon
# 38         Polygon
# 39         Polygon
# 40         Polygon
# 41    MultiPolygon
# 42    MultiPolygon
# dtype: object

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
gdf.plot(figsize=(15, 15))
# Out:
# <Axes: >

# %%
gdf.plot(figsize=(15, 15), alpha=0.5, edgecolor='k')
# Out:
# <Axes: >

# %%
gdf.plot(figsize=(15, 15), alpha=0.5, edgecolor='k', column='NAMOBJ')
# Out:
# <Axes: >

# %%
gdf.plot(figsize=(15, 15), alpha=0.5, edgecolor='k', column='NAMOBJ', legend=True)
# Out:
# <Axes: >

# %%
gdf.plot(figsize=(15, 15), alpha=0.5, edgecolor='k', column='NAMOBJ', legend=True, legend_kwds={'loc': 'upper left'})
# Out:
# <Axes: >

# %%
gdf.plot(figsize=(15, 15), alpha=0.5, edgecolor='k', column='NAMOBJ', legend=True, cmap='gist_rainbow', legend_kwds={'loc': 'upper left'})
# Out:
# <Axes: >

# %%
gdf.plot(figsize=(15, 15), alpha=0.5, edgecolor='k', column='NAMOBJ', legend=True, cmap='Paired', legend_kwds={'loc': 'upper left'})
# Out:
# <Axes: >

# %%
gdf.plot(figsize=(15, 15), alpha=0.5, edgecolor='k', column='NAMOBJ', legend=True, cmap='Set3', legend_kwds={'loc': 'upper left'})
# Out:
# <Axes: >
